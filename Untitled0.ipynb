# %%
import model
import pandas as pd
import numpy as np
reload(model)
from sklearn import metrics
from random import sample

# %%
normtrain, target, normtest, solution, test, top_test_genres, test_names = model.data()
# Out:
# dropping found duplicates

# %%
import pickle
pca = pickle.load(file('skpca.pkl'))

# %%
# from sklearn.decomposition import ProbabilisticPCA
# pca = ProbabilisticPCA(n_components='mle')
# fitted = pca.fit_transform(train)
pca_test = pca.transform(normtest)
fitted = pca.transform(normtrain)

# %%
# rebalance the data set
target.index = range(len(target.index))
pca_rebalanced, balanced_target = model.balance(1, pd.DataFrame(fitted), target)
one_train = fitted[target == 0]
print pca_rebalanced.shape
# Out:
# sanity check 0
# (1356, 1152)

# %%
# Naive Bayes on undersampled data
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(under_trained + -1*(np.min(np.array(under_trained))), under_target)
preds = nb.predict(test)
print nb.score(test, solution)
print metrics.confusion_matrix(solution, preds)

# %%
# one class svm
from sklearn.svm import OneClassSVM
sv = OneClassSVM()
sv.fit(one_train)
one_class_solutions = [i if i == 1.0 else -1 for i in solution]
one_class_preds = sv.predict(pca_test)
metrics.confusion_matrix(one_class_solutions, one_class_preds)
preds = sv.predict(pca_test)
# Out:
# OneClassSVM(cache_size=200, coef0=0.0, degree=3, gamma=0.0, kernel='rbf',
#       max_iter=-1, nu=0.5, random_state=None, shrinking=True, tol=0.001,
#       verbose=False)

# %%
reload(model)
# Out:
# <module 'model' from 'model.py'>

# %%
import pdb

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
x = 5
class_df = pd.DataFrame(index = range(x), columns = ['logreg','rfmod','sv','nb'])
recall_df = pd.DataFrame(index = range(x), columns = ['logreg','rfmod','sv','nb'])
precision_df = pd.DataFrame(index = range(x), columns = ['logreg','rfmod','sv','nb'])
fscore_df = pd.DataFrame(index = range(x), columns = ['logreg','rfmod','sv','nb'])
fbeta = pd.DataFrame(index = range(x), columns = ['logreg','rfmod','sv','nb'])
for i in range(x):
    pca_rebalanced, balanced_target = model.balance(1 + (i*1.0/5), pd.DataFrame(fitted), target)
    one_train = fitted[target == 0]
    logreg = LogisticRegression()
    rfmod = RandomForestClassifier()
    nb = MultinomialNB()
    sv = SVC()
    
    rfmod.fit(pca_rebalanced, balanced_target)
    logreg.fit(pca_rebalanced, balanced_target)
    nb.fit(pca_rebalanced + -1*(np.min(np.array(pca_rebalanced))), balanced_target)
    sv.fit(pca_rebalanced, balanced_target)
    
    preds1 = logreg.predict(pca_test)
    preds2 = rfmod.predict(pca_test)
    preds3 = nb.predict(pca_test + -1*(np.min(np.array(pca_rebalanced))))
    preds4 = sv.predict(pca_test)
    
    class_df['logreg'][i] = logreg.score(pca_test, solution)
    class_df['rfmod'][i] = rfmod.score(pca_test, solution)
    class_df['nb'][i] = nb.score(pca_test, solution)
    class_df['sv'][i] = sv.score(pca_test, solution)    
    recall_df['logreg'][i] = metrics.recall_score(solution, preds1)
    recall_df['rfmod'][i] = metrics.recall_score(solution, preds2)
    recall_df['nb'][i] = metrics.recall_score(solution, preds3)
    recall_df['sv'][i] = metrics.recall_score(solution, preds4)
    precision_df['logreg'][i] = metrics.precision_score(solution, preds1)
    precision_df['rfmod'][i] = metrics.precision_score(solution, preds2)
    precision_df['nb'][i] = metrics.precision_score(solution, preds3)
    precision_df['sv'][i] = metrics.precision_score(solution, preds4)
    fscore_df['logreg'][i] = metrics.f1_score(solution, preds1)
    fscore_df['rfmod'][i] = metrics.f1_score(solution, preds2)
    fscore_df['nb'][i] = metrics.f1_score(solution, preds3)
    fscore_df['sv'][i] = metrics.f1_score(solution, preds4)
    fbeta['logreg'][i] = metrics.fbeta_score(solution, preds1,2)
    fbeta['rfmod'][i] = metrics.fbeta_score(solution, preds2, 2)
    fbeta['nb'][i] = metrics.fbeta_score(solution, preds3, 2)
    fbeta['sv'][i] = metrics.fbeta_score(solution, preds4, 2)
    
    print '**** new iteration ****'
    print metrics.confusion_matrix(solution, preds1)
    print metrics.confusion_matrix(solution, preds2)
    print metrics.confusion_matrix(solution, preds3)
    print metrics.confusion_matrix(solution, preds4)
# Out:
# sanity check 0
# **** new iteration ****
# [[2427 1039]
#  [  66  230]]
# [[2736  730]
#  [ 100  196]]
# [[2443 1023]
#  [  94  202]]
# [[2631  835]
#  [  72  224]]
# sanity check 0
# **** new iteration ****
# [[2561  905]
#  [  69  227]]
# [[2899  567]
#  [ 125  171]]
# [[3466    0]
#  [ 296    0]]
# [[2753  713]
#  [  82  214]]
# sanity check 0
# **** new iteration ****
# [[2623  843]
#  [  74  222]]
# [[2982  484]
#  [ 131  165]]
# [[3466    0]
#  [ 296    0]]
# [[2859  607]
#  [ 103  193]]
# sanity check 0
# **** new iteration ****
# [[2651  815]
#  [  74  222]]
# [[2983  483]
#  [ 128  168]]
# [[3466    0]
#  [ 296    0]]
# [[2938  528]
#  [ 116  180]]
# sanity check 0
# **** new iteration ****
# [[2729  737]
#  [  98  198]]
# [[3034  432]
#  [ 140  156]]
# [[3466    0]
#  [ 296    0]]
# [[3102  364]
#  [ 154  142]]

# %%
print '*** CLASSIFICATION ERROR ***'
print class_df
print '*** RECALL SCORE ***'
print recall_df
print '*** PRECISION SCORE ***'
print precision_df
print '*** f1 SCORE ***'
print fscore_df
print '**** fbeta ****'
print fbeta
# Out:
# *** CLASSIFICATION ERROR ***
#       logreg      rfmod         sv         nb
# 0   0.695109  0.7721956  0.7477406  0.6036683
# 1  0.7299309  0.8067517   0.781765  0.9213184
# 2  0.7461457  0.8343966  0.8070175  0.9213184
# 3   0.764487  0.8383838  0.8359915  0.9213184
# 4  0.7857523  0.8623073  0.8545986  0.9213184
# *** RECALL SCORE ***
#       logreg      rfmod         sv         nb
# 0  0.7466216  0.6790541  0.7466216  0.6790541
# 1  0.7195946  0.6554054  0.7027027          0
# 2  0.6925676  0.5675676  0.6452703          0
# 3  0.7195946  0.5675676  0.6013514          0
# 4  0.6891892  0.4493243  0.5168919          0
# *** PRECISION SCORE ***
#       logreg      rfmod         sv         nb
# 0  0.1709203  0.2087227  0.2018265  0.1665286
# 1  0.1858639  0.2368742  0.2210414          0
# 2   0.191768  0.2533937  0.2352217          0
# 3  0.2096457  0.2592593  0.2629247          0
# 4  0.2222222   0.272541  0.2746858          0
# ...

# %%
pca_rebalanced, balanced_target = model.balance(1.20, pd.DataFrame(fitted), target)
# Out:
# sanity check 0

# %%
from sklearn.cross_validation import KFold

# %%
kf = KFold(len(balanced_target), n_folds = 100, indices=False, shuffle = True)

# %%
accuracy = []
fbeta = []
training = []
testing = []
for train, test in kf:
    mod = SVC()
    training.append(train)
    testing.append(test)
    mod.fit(pca_rebalanced[train], balanced_target[train])
    preds = mod.predict(pca_rebalanced[test])
    accuracy.append(metrics.accuracy_score(balanced_target[test], preds))
    fbeta.append(metrics.fbeta_score(balanced_target[test], preds, 2))

# %%
from matplotlib import pyplot
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['sample', 'test', 'mod']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
max(fbeta)
# Out:
# 0.27579582875960479

# %%
plot(accuracy)

# %%
accuracy = []
fbeta = []
for i in range(50):
    pca_rebalanced, balanced_target = model.balance(1.20, pd.DataFrame(fitted), target)
    mod = SVC()
    mod.fit(pca_rebalanced, balanced_target)
    preds = mod.predict(pca_test)
    accuracy.append(metrics.accuracy_score(solution, preds))
    fbeta.append(metrics.fbeta_score(solution, preds, 2))
# Out:
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0
# sanity check 0

# %%
mean(fbeta)
# Out:
# 0.49094164655959438

# %%
rfmod = RandomForestClassifier()
rfmod.fit(pca_rebalanced, balanced_target)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0)

# %%
rfmod.feature_importances_
# Out:
# array([ 0.02200148,  0.00999029,  0.00414976, ...,  0.        ,
#         0.        ,  0.        ])

# %%
mod, features = model.growforest(pca_rebalanced, balanced_target, 100)

# %%
features
# Out:
# [(0.020190457824240421, 8),
#  (0.019398056810459023, 2),
#  (0.016995802058783576, 9),
#  (0.013760256192727128, 10),
#  (0.013073454187056095, 0),
#  (0.012779108418545331, 1),
#  (0.012671621167437315, 53),
#  (0.011109403450615236, 37),
#  (0.010074074111955792, 7),
#  (0.0086959321752868232, 45),
#  (0.0084278958537010503, 43),
#  (0.0080398474443115348, 127),
#  (0.0073614526294540714, 76),
#  (0.0072954055312716305, 67),
#  (0.0070534874206273322, 13),
#  (0.0069004895148056054, 66),
#  (0.0063957997550549532, 39),
#  (0.005936281663676081, 17),
#  (0.0058916552024710312, 122),
#  (0.0058888287117235486, 24),
#  (0.0052131983729010499, 3),
#  (0.0050271051765341905, 12),
#  (0.0048538593842079713, 51),
#  (0.0045682686358836551, 70),
#  (0.0042546586519487482, 65),
#  (0.0042265919670774676, 111),
#  (0.003927380633173572, 527),
#  (0.0038978671438720082, 102),
#  (0.0038940980898330459, 50),
#  (0.003892554857692721, 14),
#  (0.0036592494458449298, 121),
# ...
