# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot
import pdb
import model
import random
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
from random import sample

# %%
model.make_encoder()

# %%
reload(model)
# Out:
# <module 'model' from 'model.py'>

# %%
'''
look at the effect of increasing the number of trees
to optimize: information gain, max features, etc
'''
# i = 1
# cv_score = []
# n_trees = []
# while i < 50:
#     i += 2
#     n_trees.append(i)
#     mod, top_features = model.growforest(encoded, i)
#     cv_score.append(model.make_predictions(test_encoded, mod))
# figure()
# plot(n_trees, cv_score)

# %%
'''
compare to svm
'''
# from sklearn.svm import SVC
# clf = SVC()
# svc_model = clf.fit(encoded_training, encoded_target)
# solutions2, predictions2 = model.make_predictions(test_encoded, svc_model)
# sum(np.array(solutions2) == predictions2)*1.0/len(predictions2)

# %%
'''
look at false positives when playcount is included
'''
to_drop = ['recent_date1','recent_date2','recent_date3','recent_date4',
            'recent_date5','registered', 'id']
# load the encoded data
encoded, test_encoded = model.data(to_drop = to_drop)
# make the model
mod, top_features = model.growforest(encoded, num_trees = 100)
# test against users who don't subscribe
user = test_encoded[test_encoded['subscriber'] == 359]
solutions, predictions, score = model.make_predictions(user, model = mod)
false_pos = model.dencode(user[predictions != 359], decode = True)

# %%
'''
strip the count features to predict new users
'''
to_drop = ['recent_date1','recent_date2','recent_date3','recent_date4',
            'recent_date5','registered', 'id', 'playcount', 'top_count1',
            'top_count2', 'top_count3', 'top_count4', 'top_count5', 'friend_count']
encoded, test_encoded = model.data(to_drop = to_drop)
mod, top_features = model.growforest(encoded, num_trees = 100)
solutions, predictions, score = model.make_predictions(test_encoded, model = mod)

# %%
reload(model)
train, test, trainun = model.data()#encode = True, reencode = True)
#train[train['subscriber'] == 1]
x = train.describe()
train.use_diff_days.hist()
print x.use_diff_days
#print train.columns
# Out:
# count    1715.000000
# mean        0.004137
# std         1.000304
# min        -0.824889
# 25%        -0.789760
# 50%        -0.438815
# 75%         0.592813
# max         4.090056
# Name: use_diff_days, dtype: float64

# %%
trainun['playcount'].hist()

# %%
'''
build model on invented class distribution
'''
reload(model)
#train, test = model.data()#encode = True, reencode = True)
zero = 0#model.dencode(0, one_off = True, decode = False)[0]
one = 1#model.dencode(1, one_off = True, decode = False)[0]
# get the training set index
subscriber_index = train[train['subscriber'] == one].index
user_index = train[train['subscriber'] == zero].index
# randomly select users
chosen = sample(list(user_index), len(subscriber_index))
# create a new training set with equal parts subsriber and users
new_train = train.ix[list(subscriber_index) + chosen]
# train the new model
mod, top_features = model.growforest(new_train, 100)
solutions3, predictions3, score3 = model.make_predictions(test, model = mod)
score3
# test on only users
# user = test[test['subscriber'] == zero]
# solutions1, predictions1, score1 = model.make_predictions(user, model = mod)
# # the false positives are users that I predicted would be subscribers
# false_pos = model.dencode(user[predictions1 != 153], decode = True)
# # test only on subscribers
# subs = test[test['subscriber'] == one]
# solutions2, predictions2, score2 = model.make_predictions(subs, model = mod)
# # the false negative are subscribers that I predicted would be users
# false_neg = model.dencode(subs[predictions2 != 359], decode = True)
# Out:
# 0.67755102040816328

# %%
top_features
# Out:
# [(0.067325233239897475, 'top_count2'),
#  (0.064998720431464291, 'playcount'),
#  (0.060026955277289067, 'top_count5'),
#  (0.057374440594219457, 'top_count1'),
#  (0.056654195844943162, 'use_diff_days'),
#  (0.054204819733646034, 'top_count4'),
#  (0.053058513595446256, 'top_count3'),
#  (0.048499543739961438, 'avg_diff_hours'),
#  (0.046132276848550875, 'hour_registered'),
#  (0.028481264061039669, 'age'),
#  (0.024967659354738433, 'friend_count'),
#  (0.020772145241583568, 'rock'),
#  (0.016941638951734835, 'pop'),
#  (0.01404989496930802, 'friend_sub'),
#  (0.013947827133554334, 'indie'),
#  (0.012721006165819402, 'electronic'),
#  (0.010840786469464686, 'playlists'),
#  (0.01070597292356734, 'alternative'),
#  (0.010619149762670595, 'Hip-Hop'),
#  (0.01035650445484684, 'classic rock'),
#  (0.0097485015692365447, 'gender'),
#  (0.0094676073987837762, 'US'),
#  (0.0093072767404080142, 'folk'),
#  (0.0084411233923099623, 'jazz'),
#  (0.0083285946743970538, 'mysterious'),
#  (0.0077000601583706385, 'soul'),
#  (0.0075930411578453063, 'rnb'),
#  (0.0074426721758893847, 'image'),
#  (0.0072412112952597394, 'alternative rock'),
#  (0.0065766937866593442, 'ZA'),
#  (0.0062617017917899285, 'indie rock'),
#  (0.0061931765398258289, 'female vocalists'),
#  (0.0060271629112416004, 'mpb'),
#  (0.0059257157497148586, 'pop punk'),
#  (0.0055473244501475383, 'blues'),
#  (0.0054548792585214336, 'country'),
#  (0.0052939004838600257, 'hard rock'),
#  (0.0044294760074799914, 'singer-songwriter'),
#  (0.0043122116596625163, 'dance'),
#  (0.0040070427424040503, 'reggae'),
#  (0.0039192898693495579, 'UK'),
#  (0.0038640546837307725, 'Disco'),
#  (0.0037921207167070652, 'Macedonian'),
#  (0.0037592406675716729, 'rap'),
#  (0.0037444521537524705, 'NO'),
#  (0.0036932666336919545, 'Progressive rock'),
#  (0.0036061305578250387, 'post-hardcore'),
#  (0.0035202297446485483, 'german'),
#  (0.0032954303390479033, 'NL'),
#  (0.0032184422351383916, 'hardcore'),
#  (0.003211773306944876, 'DE'),
#  (0.0031663300277192407, 'pop rock'),
#  (0.003144305552188816, 'latin'),
#  (0.0030393345912183211, 'Soundtrack'),
#  (0.0029806636333964374, 'dream pop'),
#  (0.0029717883548115152, 'Garage Rock'),
#  (0.0029212038999633433, 'CA'),
#  (0.0029055367173653353, 'event_count'),
#  (0.0028057189220896429, 'russian rock'),
#  (0.0026844801460772769, 'post-punk'),
#  (0.0024808124060559495, 'Deutschrock'),
#  (0.002477376592896124, 'BR'),
#  (0.0024694169011229687, 'screamo'),
#  (0.0024290088734700926, 'metalcore'),
#  (0.0023946687728425499, 'black metal'),
#  (0.0023873507404672512, 'Nu Metal'),
#  (0.0022661026930908511, 'britpop'),
#  (0.0022387630741605982, 'Stoner Rock'),
#  (0.0022379734488316666, 'post-rock'),
#  (0.0021002784612322222, 'Smooth Jazz'),
#  (2.546335965468659e-05, 'FI'),
#  (2.3003635283533783e-05, 'eurodance'),
#  (1.8328723460302385e-05, '70s'),
#  (1.6865807347872267e-05, 'MY'),
#  (1.6395723933416663e-05, 'rockabilly'),
#  (1.4872899987263101e-05, 'deathcore'),
#  (1.1093898516193979e-05, 'J-rock'),
#  (1.1078797456930502e-05, 'dub'),
#  (1.0417729490935668e-05, 'Korean'),
#  (9.2209714093878143e-06, 'psychobilly'),
#  (7.6093867726435581e-06, 'Power metal'),
#  (4.3150318563253374e-06, 'Dirty South'),
#  (3.7474555749770848e-06, 'power pop'),
#  (2.8990977017512639e-06, 'new wave'),
#  (1.2954246683059773e-06, 'tech house'),
#  (1.1485348583073414e-06, 'countrycore'),
#  (0.0, 'young money'),
#  (0.0, 'world fusion'),
#  (0.0, 'world'),
#  (0.0, 'witch house'),
#  (0.0, 'west coast'),
#  (0.0, 'visual kei'),
#  (0.0, 'violin'),
#  (0.0, 'viking metal'),
#  (0.0, 'vietnamese'),
#  (0.0, 'video game remixes'),
#  (0.0, 'video game music'),
#  (0.0, 'valentin elizalde'),
#  (0.0, 'underground hip-hop'),
#  (0.0, 'twee'),
#  (0.0, 'turntablism'),
#  (0.0, 'turkish rock'),
#  (0.0, 'trova'),
#  (0.0, 'texas country'),
#  (0.0, 'tejano'),
#  (0.0, 'teenbeat'),
#  (0.0, 'tango'),
#  (0.0, 't di'),
#  (0.0, 'synthetic jam'),
#  (0.0, 'stoner metal'),
#  (0.0, 'spanish hip-hop'),
#  (0.0, 'spanish guitar'),
#  (0.0, 'space rock'),
#  (0.0, 'southern rap'),
#  (0.0, 'songwriter'),
#  (0.0, 'slowcore'),
#  (0.0, 'slovak'),
#  (0.0, 'ska punk'),
#  (0.0, 'sid metal'),
#  (0.0, 'sertanejo'),
#  (0.0, 'sermons'),
#  (0.0, 'sergio vega'),
#  (0.0, 'semana santa'),
#  (0.0, 'science'),
#  (0.0, 'schranz'),
#  (0.0, 'scat goregrind'),
#  (0.0, 'sattar'),
#  (0.0, 'santoor'),
#  (0.0, 'samba'),
#  (0.0, 'salsa'),
#  (0.0, 'russian chanson'),
#  (0.0, 'romantic'),
#  (0.0, 'roger whittaker'),
#  (0.0, 'rocksteady'),
#  (0.0, 'rock-n-roll'),
#  (0.0, 'rock mexicano'),
#  (0.0, 'rock gaucho'),
#  (0.0, 'rock chileno'),
#  (0.0, 'rock catala'),
#  (0.0, 'rock brasil'),
#  (0.0, 'riot grrrl'),
#  (0.0, 'raw'),
#  (0.0, 'rastatales'),
#  (0.0, 'rapcore'),
#  (0.0, 'ranchera'),
#  (0.0, 'r&b'),
#  (0.0, 'quebec'),
#  (0.0, 'qawwali'),
#  (0.0, 'puamedia-ru'),
#  (0.0, 'psycho'),
#  (0.0, 'powerviolence'),
#  (0.0, 'powerpop'),
#  (0.0, 'post-huipizdacore'),
#  (0.0, 'portuguese'),
#  (0.0, 'poezja spiewana'),
#  (0.0, 'poetry'),
#  (0.0, 'piano rock'),
#  (0.0, 'persian rock'),
#  (0.0, 'perrones'),
#  (0.0, 'pepe aguilar'),
#  (0.0, 'party'),
#  (0.0, 'parody'),
#  (0.0, 'pagan metal'),
#  (0.0, 'oldschool'),
#  (0.0, 'oldies'),
#  (0.0, 'nu jazz'),
#  (0.0, 'nsbm'),
#  (0.0, 'noise rock'),
#  (0.0, 'noise'),
#  (0.0, 'new york'),
#  (0.0, 'new rave'),
#  (0.0, 'nerdcore'),
#  (0.0, 'neofolk'),
#  (0.0, 'nederhop'),
#  (0.0, 'nagoya kei'),
#  (0.0, 'musicas que mexem com meu coracao'),
#  (0.0, 'musica gospel'),
#  (0.0, 'mod'),
#  (0.0, 'minimalism'),
#  (0.0, 'minimal techno'),
#  (0.0, 'mexican'),
#  (0.0, 'merengue'),
#  (0.0, 'memphis rap'),
#  (0.0, 'medieval'),
#  (0.0, 'mathcore'),
#  (0.0, 'martial industrial'),
#  (0.0, 'malay'),
#  (0.0, 'maite perroni'),
#  (0.0, 'magnatune'),
#  (0.0, 'macross'),
#  (0.0, 'lesser known yet streamable artists'),
#  (0.0, 'les legions noires'),
#  (0.0, 'latvian'),
#  (0.0, 'latin pop'),
#  (0.0, 'kurdish'),
#  (0.0, 'krautrock'),
#  (0.0, 'klezmer'),
#  (0.0, 'kircore'),
#  (0.0, 'kids'),
#  (0.0, 'kassel'),
#  (0.0, 'k?lsch'),
#  (0.0, 'junes'),
#  (0.0, 'juggalo'),
#  (0.0, 'jewish'),
#  (0.0, 'japanese'),
#  (0.0, 'islamic'),
#  (0.0, 'irish'),
#  (0.0, 'infantil'),
#  (0.0, 'industrial black metal'),
#  (0.0, 'indonesian'),
#  (0.0, 'indonesia'),
#  (0.0, 'indie pop'),
#  (0.0, 'indian classical'),
#  (0.0, 'icelandic'),
#  (0.0, 'hyphy'),
#  (0.0, 'hungarian'),
#  (0.0, 'horror punk'),
#  (0.0, 'hiphop'),
#  (0.0, 'hip hop'),
#  (0.0, 'hardstyle'),
#  (0.0, 'hardcore punk'),
#  (0.0, 'happy hardcore'),
#  (0.0, 'hands up'),
#  (0.0, 'gypsy punk'),
#  (0.0, 'greek rock'),
#  (0.0, 'gospel brasil'),
#  (0.0, 'gospel'),
#  (0.0, 'glitch-hop'),
#  (0.0, 'glitch'),
#  (0.0, 'glam rock'),
#  (0.0, 'germany'),
#  (0.0, 'french rap'),
#  (0.0, 'freestyle'),
#  (0.0, 'free jazz'),
#  (0.0, 'francophone'),
#  (0.0, 'franco de vita'),
#  (0.0, 'folktronica'),
#  (0.0, 'folk rock'),
#  (0.0, 'folk punk'),
#  (0.0, 'folk metal'),
#  (0.0, 'flute'),
#  (0.0, 'finnish'),
#  (0.0, 'female vocalist'),
#  (0.0, 'female vocal'),
#  (0.0, 'ethereal'),
#  (0.0, 'ersguterjunge'),
#  (0.0, 'enka'),
#  (0.0, 'emocore'),
#  (0.0, 'emmanuel'),
#  (0.0, 'electropunk'),
#  (0.0, 'electronica'),
#  (0.0, 'electrobrega'),
#  (0.0, 'electro house'),
#  (0.0, 'duranguense'),
#  (0.0, 'drone'),
#  (0.0, 'disco polo'),
#  (0.0, 'digital hardcore'),
#  (0.0, 'depressive black metal'),
#  (0.0, 'dep trai'),
#  (0.0, 'deep house'),
#  (0.0, 'david gilmour'),
#  (0.0, 'darkwave'),
#  (0.0, 'dark electro'),
#  (0.0, 'dark cabaret'),
#  (0.0, 'dark ambient'),
#  (0.0, 'danish'),
#  (0.0, 'd-beat'),
#  (0.0, 'cybergrind'),
#  (0.0, 'cuban'),
#  (0.0, 'cuba'),
#  (0.0, 'crunkcore'),
#  (0.0, 'croatian'),
#  (0.0, 'corridos'),
#  (0.0, 'corrido mexicano'),
#  (0.0, 'cool clubbing'),
#  (0.0, 'conjunto primavera'),
#  (0.0, 'classic'),
#  (0.0, 'christmas'),
#  (0.0, 'choir'),
#  (0.0, 'chiptune'),
#  (0.0, 'chillout'),
#  (0.0, 'chile'),
#  (0.0, 'childrens music'),
#  (0.0, 'childrens'),
#  (0.0, 'chicago'),
#  (0.0, 'chayanne'),
#  (0.0, 'charlie parker'),
#  (0.0, 'chanson francaise'),
#  (0.0, 'chanson'),
#  (0.0, 'celtic punk'),
#  (0.0, 'cello'),
#  (0.0, 'catalan'),
#  (0.0, 'catala'),
#  (0.0, 'cardio-wave'),
#  (0.0, 'capoeira'),
#  (0.0, 'canton jones'),
#  (0.0, 'cantautor'),
#  (0.0, 'cafe del mar'),
#  (0.0, 'burning spirits'),
#  (0.0, 'bulgarian'),
#  (0.0, 'bubblegum'),
#  (0.0, 'british'),
#  (0.0, 'breakcore'),
#  (0.0, 'breakbeat'),
#  (0.0, 'brasil'),
#  (0.0, 'boleros'),
#  (0.0, 'bluegrass'),
#  (0.0, 'black gospel'),
#  (0.0, 'bitpop'),
#  (0.0, 'bhajan'),
#  (0.0, 'bellydance'),
#  (0.0, 'belgian'),
#  (0.0, 'beatbox'),
#  (0.0, 'bass'),
#  (0.0, 'baroque pop'),
#  (0.0, 'baroque'),
#  (0.0, 'ballet'),
#  (0.0, 'bachata'),
#  (0.0, 'avantgarde'),
#  (0.0, 'arabic'),
#  (0.0, 'anticon'),
#  (0.0, 'anti-folk'),
#  (0.0, 'anime'),
#  (0.0, 'andy borg'),
#  (0.0, 'anarcho-punk'),
#  (0.0, 'afrobeat'),
#  (0.0, 'acid jazz'),
#  (0.0, 'abstract hip-hop'),
#  (0.0, 'a cappella'),
#  (0.0, 'a capella'),
#  (0.0, 'Weltmusik'),
#  (0.0, 'VG'),
#  (0.0, 'VE'),
#  (0.0, 'UY'),
#  (0.0, 'Turkish Pop'),
#  (0.0, 'The-Dream'),
#  (0.0, 'TR'),
#  (0.0, 'TF'),
#  (0.0, 'Symphonic Black Metal'),
#  (0.0, 'Surf'),
#  (0.0, 'Spanish Rock'),
#  (0.0, 'Southern Rock'),
#  (0.0, 'Sludge'),
#  (0.0, 'Schlager'),
#  (0.0, 'SK'),
#  (0.0, 'SJ'),
#  (0.0, 'SI'),
#  (0.0, 'SG'),
#  (0.0, 'Romantica'),
#  (0.0, 'Rock en Espanol'),
#  (0.0, 'Rock and Roll'),
#  (0.0, 'Rock Argentino'),
#  (0.0, 'Radio'),
#  (0.0, 'RS'),
#  (0.0, 'RAC'),
#  (0.0, 'QA'),
#  (0.0, 'Progressive Metalcore'),
#  (0.0, 'Pornorap'),
#  (0.0, 'Persian'),
#  (0.0, 'Pagode'),
#  (0.0, 'Pagan'),
#  (0.0, 'PY'),
#  (0.0, 'PT'),
#  (0.0, 'PH'),
#  (0.0, 'PE'),
#  (0.0, 'Ostrock'),
#  (0.0, 'OPM'),
#  (0.0, 'OC ReMix'),
#  (0.0, 'Notre Dame de Paris'),
#  (0.0, 'Nederlandstalig'),
#  (0.0, 'Nature'),
#  (0.0, 'Natural Sounds'),
#  (0.0, 'NZ'),
#  (0.0, 'NDW'),
#  (0.0, 'My 64'),
#  (0.0, 'Musica Cristiana'),
#  (0.0, 'Marsch'),
#  (0.0, 'MV'),
#  (0.0, 'MD'),
#  (0.0, 'Lucky Ali'),
#  (0.0, 'LT'),
#  (0.0, 'LI'),
#  (0.0, 'LDS'),
#  (0.0, 'LB'),
#  (0.0, 'Kristina Bach'),
#  (0.0, 'Komander'),
#  (0.0, 'KZ'),
#  (0.0, 'KR'),
#  (0.0, 'Johnnys entertainment'),
#  (0.0, 'Joan Sebastian'),
#  (0.0, 'Japanese City Pop'),
#  (0.0, 'JP'),
#  (0.0, 'Israeli Rock'),
#  (0.0, 'Iranian'),
#  (0.0, 'Indian'),
#  (0.0, 'IQ'),
#  (0.0, 'IN'),
#  (0.0, 'IL'),
#  (0.0, 'IE'),
#  (0.0, 'ID'),
#  (0.0, 'Horror Surf'),
#  (0.0, 'Hong Kong'),
#  (0.0, 'Hoerspiel'),
#  (0.0, 'Hoerbuch'),
#  (0.0, 'Hard Trance'),
#  (0.0, 'HU'),
#  (0.0, 'Gypsy'),
#  (0.0, 'Grime'),
#  (0.0, 'Greek'),
#  (0.0, 'Gothic'),
#  (0.0, 'German RnB'),
#  (0.0, 'Gangsta Rap'),
#  (0.0, 'GR'),
#  (0.0, 'GH'),
#  (0.0, 'G-funk'),
#  (0.0, 'Flamenco'),
#  (0.0, 'Filipino'),
#  (0.0, 'Favourites'),
#  (0.0, 'FR'),
#  (0.0, 'Eurovision'),
#  (0.0, 'EG'),
#  (0.0, 'Disney'),
#  (0.0, 'Dipset'),
#  (0.0, 'Deutschrap'),
#  (0.0, 'Death Rap'),
#  (0.0, 'DK'),
#  (0.0, 'Curitiba'),
#  (0.0, 'Crust'),
#  (0.0, 'Crunk Rock'),
#  (0.0, 'Colombia'),
#  (0.0, 'Chicano Rap'),
#  (0.0, 'Chanson Fran?aise'),
#  (0.0, 'Canadian'),
#  (0.0, 'CR'),
#  (0.0, 'CO'),
#  (0.0, 'CN'),
#  (0.0, 'CMAR 2011'),
#  (0.0, 'CL'),
#  (0.0, 'CH'),
#  (0.0, 'CC'),
#  (0.0, 'C-pop'),
#  (0.0, 'Broadway'),
#  (0.0, 'Breakaway'),
#  (0.0, 'Bossa Nova'),
#  (0.0, 'Bosnian'),
#  (0.0, 'Blasmusik'),
#  (0.0, 'Bhangra'),
#  (0.0, 'Berlin'),
#  (0.0, 'Bay Area'),
#  (0.0, 'Barbershop'),
#  (0.0, 'BG'),
#  (0.0, 'BE'),
#  (0.0, 'BANDA'),
#  (0.0, 'Axe'),
#  (0.0, 'Aussie'),
#  (0.0, 'American Idol'),
#  (0.0, 'All'),
#  (0.0, 'AR'),
#  (0.0, 'AQ'),
#  (0.0, 'AF'),
#  (0.0, '90s'),
#  (0.0, '8-bit'),
#  (0.0, '60s'),
#  (-1.6763344788720626e-06, 'dubstep'),
#  (-6.679209161532107e-06, 'groove metal'),
#  (-1.0981282243537192e-05, 'soft rock'),
#  (-1.509617971482379e-05, 'kinderliedje'),
#  (-2.1863625144809065e-05, 'VA'),
#  (-3.2664807316734322e-05, 'k-pop'),
#  (-4.6842443250087489e-05, 'New Zealand'),
#  (-4.8037867603142379e-05, 'eurobeat'),
#  (-6.3619720032665681e-05, 'House')]

# %%
from sklearn.svm import OneClassSVM
oneclass = OneClassSVM()
#train, test = model.data()

# %%
# one class svm
new_train = train[train['subscriber'] == zero]
oneclass_mod = oneclass.fit(new_train.drop('subscriber', axis = 1))

# %%
solutions4, predictions4, score4 = model.make_predictions(test, model = oneclass_mod)
sum(predictions4 == -1.)
# Out:
# 3738

# %%
subs = train[train['subscriber'] == one]
users = train.ix[chosen]
new_train['avg_diff_hours'].hist(by = new_train['subscriber'])
#plt.figure()
#subs['avg_diff_hours'].hist()
#users['avg_diff_hours'].hist()
print one
# Out:
# 3803

# %%
import networkx as nx
import graphan
reload(graphan)
graph = graphan.make_graph()

# %%
subs_list = nx.connected_component_subgraphs(graph)

# %%
clusters = nx.clustering(graph)
max(clusters, key=clusters.get)
# Out:
# '8290121'

# %%
#subs_list[1]
x = subs_list[1].node
x
# Out:
# {'12130441': {},
#  '2130609': {},
#  '2467256': {},
#  '2625510': {},
#  '2751570': {},
#  '2880251': {},
#  '3374844': {},
#  '3587683': {},
#  '3597468': {},
#  '3606286': {},
#  '3613963': {},
#  '3622571': {},
#  '3688160': {},
#  '3739127': {'color': '0'},
#  '3740018': {},
#  '3759288': {},
#  '3773620': {},
#  '3830473': {},
#  '4069132': {},
#  '4205622': {},
#  '4285108': {},
#  '4293095': {},
#  '4299177': {},
#  '4434481': {},
#  '4467793': {},
#  '4566186': {'color': '0'},
#  '4657302': {},
#  '4841668': {},
#  '4966325': {},
#  '5000250': {},
#  '5016784': {},
#  '5408304': {},
#  '5594668': {},
#  '5909684': {},
#  '5944688': {},
#  '5961143': {},
#  '6241676': {},
#  '6268095': {},
#  '6276626': {},
#  '6309519': {},
#  '6436573': {},
#  '9527167': {}}

# %%
nx.draw(subs_list[6], node_color=nx.node_attribute_xy(subs_list[2],'color'))

# %%
nx.node_attribute_xy(graph, color
